# %% [markdown]
# # Week 4 notes

# %% [markdown]
# OSI Model
# https://www.geeksforgeeks.org/computer-networks/open-systems-interconnection-model-osi/
#
#
# - Application
# - Presentation
# - Session
# - Transport
# - Network
# - Data Link
# - Physical
